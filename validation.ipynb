# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy
import pandas as pd
# %matplotlib notebook

# %%
validation_data = np.loadtxt("validation_data/trail_validation_04102019.csv", delimiter=',')
validation_data
# Out:
# array([[ 5.58759 , 67.921   ],
#        [ 2.02292 , 76.3187  ],
#        [ 8.04126 , 74.176   ],
#        [ 0.955017, 69.8448  ],
#        [ 8.4376  , 67.7916  ],
#        [ 7.1964  , 78.2188  ],
#        [ 2.61638 , 61.6036  ],
#        [ 9.06198 , 65.5798  ],
#        [ 9.64201 , 72.6178  ],
#        [ 5.65504 , 79.1688  ],
#        [ 0.655495, 61.1469  ],
#        [ 7.37006 , 77.2001  ],
#        [ 4.71587 , 72.7685  ],
#        [ 6.99509 , 68.9507  ],
#        [ 9.74016 , 75.7559  ],
#        [ 5.33441 , 67.0059  ],
#        [ 7.07707 , 64.0545  ],
#        [ 4.9238  , 64.8025  ],
#        [ 4.46296 , 69.2392  ]])

# %%
vector_data = np.loadtxt("vectorgeom", delimiter=',')
vector_data
# Out:
# array([[66.375,  8.875],
#        [73.625, -3.875],
#        [75.875,  3.625],
#        [60.375, -9.625],
#        [65.125,  7.125],
#        [71.625, -9.375],
#        [66.125, -1.125],
#        [71.375,  4.625],
#        [68.375, -2.375],
#        [69.125, -5.125],
#        [60.625, -0.875],
#        [78.875, -6.125],
#        [65.625, -8.625],
#        [76.625, -9.625],
#        [73.375, -0.625],
#        [62.625, -8.625],
#        [65.625, -6.625],
#        [76.125,  8.125],
#        [68.125,  3.125],
#        [65.375, -4.125],
#        [67.125, -0.875],
#        [68.875,  0.875],
#        [68.625,  6.375],
#        [68.875,  5.625],
#        [79.125, -5.375],
#        [61.375,  2.375],
#        [70.375, -3.125],
#        [63.375,  3.125],
#        [72.125,  6.875],
#        [67.125, -3.625],
#        [66.125,  2.875],
#        [63.625,  1.875],
#        [61.625, -2.125],
#        [62.875, -9.375],
#        [62.375, -7.125],
#        [69.375,  4.375]])

# %%
from scipy.io import netcdf_file
import os

f = netcdf_file(os.path.join(os.path.abspath('') ,"04102019.nc"))
lat = f.variables['latitude'].data
long = f.variables['longitude'].data
vel_u = f.variables['ugos'].data.squeeze()
vel_v = f.variables['vgos'].data.squeeze()

# %%
longm, latm = np.meshgrid(long, lat)

plt.plot(vector_data[:,1],vector_data[:,0],'y.', markersize=10, label='Vector Geometry')
plt.plot(validation_data[:,0],validation_data[:,1],'c.', markersize=10, label='Actual')
plt.quiver(longm, latm, vel_u, vel_v, color='r', scale=5)
plt.gca().set_aspect('equal')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">
